# %%
import os
from pathlib import Path
import time
from copy import deepcopy

from tqdm import trange, tqdm

import cantera as ct
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA, IncrementalPCA

from chem_operator.utils import get_mechanism_file, to_numpy
from chem_operator.datasets import (
    CaseParameters, CaseSimulator, SimulationRecord, SimulationDatasetGenerator, ChemOperatorDataset    
)

import torch

prog_path = Path(os.path.abspath(""))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running Cantera version: {ct.__version__}")
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# Running Cantera version: 3.2.0

# %%
dataset = ChemOperatorDataset(
    path=prog_path.parent / "datasets" / "q2d_cmr" / "q2d_cmr_train.h5",
    full_trajectory_mode=False,
    dtype=torch.float32,
    coordinate_name="z"
    # n_steps_input=n_steps_input,
    # n_steps_output=n_steps_output,
    # dt_stride=dt_stride,
    # state_variables=state_variables,
    # time_key=time_key,
    # trajectory_parameters=trajectory_parameters,
)

# %%
len(dataset)
# Out:
# 63

# %%
dataset[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dataset[0]
#
# File ~/SURF/experiment-v2/src/chem_operator/datasets.py:852, in ChemOperatorDataset.__getitem__(self, index)
#     822 source_coordinate_name = self.source_coordinate_names[case_name]
#     823 metadata.update(
#     824     {
#     825         "task": self.task,
#    (...)    836     }
#     837 )
#     839 return {
#     840     "input_fields": self._load_fields(
#     841         case,
#     842         self.input_fields or (),
#     843         input_indices,
#     844         n_steps,
#     845     ),
#     846     "output_fields": self._load_fields(
#     847         case,
#     848         self.output_fields or (),
#     849         output_indices,
#     850         n_steps,
#     851     ),
# --> 852     "constant_inputs": self._load_constants(case),
#     853     "input_coordinates": self._load_coordinates(
#     854         case,
#     855         input_indices,
#     856         n_steps,
#     857         source_coordinate_name,
#     858     ),
#     859     "output_coordinates": self._load_coordinates(
#     860         case,
#     861         output_indices,
#     862         n_steps,
#     863         source_coordinate_name,
#     864     ),
#     865     "metadata": metadata,
#     866 }
#
# File ~/SURF/experiment-v2/src/chem_operator/datasets.py:789, in ChemOperatorDataset._load_constants(self, case)
#     787 constants = {}
#     788 for name in self.constant_inputs or ():
# --> 789     constants[name] = self._to_tensor(
#     790         self._read_constant(case["constants"], name),
#     791         name=f"constants/{name}",
#     792     )
#     793 return constants
#
# File ~/SURF/experiment-v2/src/chem_operator/datasets.py:523, in ChemOperatorDataset._to_tensor(self, value, name)
#     521 array = np.asarray(value)
#     522 if array.dtype.kind in {"O", "S", "U"}:
# --> 523     raise TypeError(f"{name!r} is non-numeric and cannot be a tensor.")
#     524 tensor = torch.as_tensor(array)
#     525 if self.dtype is not None:
#
# TypeError: 'constants/GASCTIFILE_LUMEN' is non-numeric and cannot be a tensor.
